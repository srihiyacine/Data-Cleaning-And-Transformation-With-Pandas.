# %% [markdown]
# <a href="https://colab.research.google.com/github/srihiyacine/Data-Cleaning-And-Transformation-With-Pandas./blob/main/Data_Cleaning_And_Transformation_With_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/house_prices.csv")

# %%
df.head(10)
# Out:
#                             street            city    zip state  beds  baths  \
# 0                     3526 HIGH ST      SACRAMENTO  95838    CA     2      1
# 1                      51 OMAHA CT      SACRAMENTO  95823    CA     3      1
# 2                   2796 BRANCH ST      SACRAMENTO  95815    CA     2      1
# 3                 2805 JANETTE WAY      SACRAMENTO  95815    CA     2      1
# 4                  6001 MCMAHON DR      SACRAMENTO  95824    CA     2      1
# 5               5828 PEPPERMILL CT      SACRAMENTO  95841    CA     3      1
# 6              6048 OGDEN NASH WAY      SACRAMENTO  95842    CA     3      2
# 7                    2561 19TH AVE      SACRAMENTO  95820    CA     3      1
# 8  11150 TRINITY RIVER DR Unit 114  RANCHO CORDOVA  95670    CA     2      2
# 9                     7325 10TH ST       RIO LINDA  95673    CA     3      2
#
#    sq__ft         type   sale_date  price   latitude   longitude
# ...

# %%
df.tail(8)
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 977      5 BISHOPGATE CT       SACRAMENTO  95823    CA     4      2    1329
# 978     5601 REXLEIGH DR       SACRAMENTO  95823    CA     4      2    1715
# 979     1909 YARNELL WAY        ELK GROVE  95758    CA     3      2    1262
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
#             type   sale_date   price   latitude   longitude
# 977  Residential  2008-05-15  229500  38.467936 -121.445477
# 978  Residential  2008-05-15  230000  38.445342 -121.441504
# 979  Residential  2008-05-15  230000  38.417382 -121.484325
# ...

# %%
df.shape
# Out:
# (985, 12)

# %%
df.columns
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %%
df.dtypes
# Out:
# street        object
# city          object
# zip            int64
# state         object
# beds           int64
# baths          int64
# sq__ft         int64
# type          object
# sale_date     object
# price          int64
# latitude     float64
# longitude    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    int64
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.5+ KB

# %%
df.describe()
# Out:
#                 zip        beds       baths       sq__ft          price  \
# count    985.000000  985.000000  985.000000   985.000000     985.000000
# mean   95750.697462    2.911675    1.776650  1314.916751  234144.263959
# std       85.176072    1.307932    0.895371   853.048243  138365.839085
# min    95603.000000    0.000000    0.000000     0.000000    1551.000000
# 25%    95660.000000    2.000000    1.000000   952.000000  145000.000000
# 50%    95762.000000    3.000000    2.000000  1304.000000  213750.000000
# 75%    95828.000000    4.000000    2.000000  1718.000000  300000.000000
# max    95864.000000    8.000000    5.000000  5822.000000  884790.000000
#
#          latitude   longitude
# count  985.000000  985.000000
# mean    38.607732 -121.355982
# std      0.145433    0.138278
# min     38.241514 -121.551704
# 25%     38.482717 -121.446127
# 50%     38.626582 -121.376220
# 75%     38.695589 -121.295778
# max     39.020808 -120.597599

# %%
df.isnull().sum()
# Out:
# street       0
# city         0
# zip          0
# state        0
# beds         0
# baths        0
# sq__ft       0
# type         0
# sale_date    0
# price        0
# latitude     0
# longitude    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 zip        beds       baths       sq__ft          price  \
# count    985.000000  985.000000  985.000000   985.000000     985.000000
# mean   95750.697462    2.911675    1.776650  1314.916751  234144.263959
# std       85.176072    1.307932    0.895371   853.048243  138365.839085
# min    95603.000000    0.000000    0.000000     0.000000    1551.000000
# 25%    95660.000000    2.000000    1.000000   952.000000  145000.000000
# 50%    95762.000000    3.000000    2.000000  1304.000000  213750.000000
# 75%    95828.000000    4.000000    2.000000  1718.000000  300000.000000
# max    95864.000000    8.000000    5.000000  5822.000000  884790.000000
#
#          latitude   longitude
# count  985.000000  985.000000
# mean    38.607732 -121.355982
# std      0.145433    0.138278
# min     38.241514 -121.551704
# 25%     38.482717 -121.446127
# 50%     38.626582 -121.376220
# 75%     38.695589 -121.295778
# max     39.020808 -120.597599

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df["city"].value_counts()
# Out:
# SACRAMENTO         439
# ELK GROVE          114
# LINCOLN             72
# ROSEVILLE           48
# CITRUS HEIGHTS      35
# ANTELOPE            33
# RANCHO CORDOVA      28
# EL DORADO HILLS     23
# GALT                21
# NORTH HIGHLANDS     21
# CARMICHAEL          20
# FOLSOM              17
# ROCKLIN             17
# RIO LINDA           13
# ORANGEVALE          11
# PLACERVILLE         10
# CAMERON PARK         9
# FAIR OAKS            9
# WILTON               5
# AUBURN               5
# GOLD RIVER           4
# ELVERTA              4
# WEST SACRAMENTO      3
# RANCHO MURIETA       3
# POLLOCK PINES        3
# GRANITE BAY          3
# LOOMIS               2
# EL DORADO            2
# MATHER               1
# PENRYN               1
# MEADOW VISTA         1
# FORESTHILL           1
# DIAMOND SPRINGS      1
# SHINGLE SPRINGS      1
# COOL                 1
# WALNUT GROVE         1
# GARDEN VALLEY        1
# SLOUGHHOUSE          1
# GREENWOOD            1
# ...

# %%
df["state"].value_counts()
# Out:
# CA    982
# Name: state, dtype: int64

# %%
df["type"].value_counts()
# Out:
# Residential     914
# Condo            54
# Multi-Family     13
# Unkown            1
# Name: type, dtype: int64

# %%
df["price"].hist()
# Out:
# <Axes: >

# %%
len(df["city"].value_counts())
# Out:
# 39

# %%
df["beds"].value_counts()
# Out:
# 3    413
# 4    257
# 2    132
# 0    107
# 5     59
# 1     10
# 6      3
# 8      1
# Name: beds, dtype: int64

# %%
df["beds"].value_counts().sort_index()
# Out:
# 0    107
# 1     10
# 2    132
# 3    413
# 4    257
# 5     59
# 6      3
# 8      1
# Name: beds, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["beds"].value_counts())
# Out:
# pandas.core.series.Series

# %%
df["baths"].value_counts()
# Out:
# 2    543
# 1    179
# 3    132
# 0    107
# 4     19
# 5      2
# Name: baths, dtype: int64

# %%
df["baths"].value_counts().sort_index()
# Out:
# 0    107
# 1    179
# 2    543
# 3    132
# 4     19
# 5      2
# Name: baths, dtype: int64

# %%
df.set_index("type", inplace=True)
df.head()
# Out:
#                        street        city    zip state  beds  baths  sq__ft  \
# type
# Residential      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# Residential       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# Residential    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# Residential  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# Residential   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#               sale_date  price   latitude   longitude
# type
# Residential  2008-05-21  59222  38.631913 -121.434879
# Residential  2008-05-21  68212  38.478902 -121.431028
# Residential  2008-05-21  68880  38.618305 -121.443839
# Residential  2008-05-21  69307  38.616835 -121.439146
# Residential  2008-05-21  81900  38.519470 -121.435768

# %%
df.shape
# Out:
# (982, 11)

# %%
df.index = df["city"]
df.head()
# Out:
#                       street        city    zip state  beds  baths  sq__ft  \
# city
# SACRAMENTO      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# SACRAMENTO       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# SACRAMENTO    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# SACRAMENTO  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# SACRAMENTO   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#              sale_date  price   latitude   longitude
# city
# SACRAMENTO  2008-05-21  59222  38.631913 -121.434879
# SACRAMENTO  2008-05-21  68212  38.478902 -121.431028
# SACRAMENTO  2008-05-21  68880  38.618305 -121.443839
# SACRAMENTO  2008-05-21  69307  38.616835 -121.439146
# SACRAMENTO  2008-05-21  81900  38.519470 -121.435768

# %%
df.index.name
# Out:
# 'city'

# %%
df.loc[["SACRAMENTO", "ELK GROVE"]].shape
# Out:
# (552, 11)

# %%
df.index.value_counts()
# Out:
# 0      1
# 647    1
# 649    1
# 650    1
# 651    1
#       ..
# 333    1
# 334    1
# 335    1
# 336    1
# 984    1
# Length: 985, dtype: int64

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft   sale_date  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836  2008-05-21
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167  2008-05-21
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796  2008-05-21
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852  2008-05-21
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797  2008-05-21
#
#    price   latitude   longitude
# 0  59222  38.631913 -121.434879
# 1  68212  38.478902 -121.431028
# 2  68880  38.618305 -121.443839
# 3  69307  38.616835 -121.439146
# 4  81900  38.519470 -121.435768

# %%
import plotly.express as px

fig = px.scatter_geo(df, lon="longitude",
                          lat="latitude",
                          hover_name="city",
                          color = "city",
                          size="price")
fig.update_geos(projection_type="mercator")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16, 10))
sns.barplot(x=df["city"], y=df["price"])

# Adding labels and title
plt.xlabel('City')
plt.ylabel('Price')
plt.title('Bar Plot Example')

plt.xticks(rotation=60)

# Displaying the plot
plt.show()

# %%
sns.scatterplot(x=df["", ])

# %%
df.describe()
# Out:
#                 zip        beds       baths       sq__ft          price  \
# count    985.000000  985.000000  985.000000   985.000000     985.000000
# mean   95750.697462    2.911675    1.776650  1314.916751  234144.263959
# std       85.176072    1.307932    0.895371   853.048243  138365.839085
# min    95603.000000    0.000000    0.000000     0.000000    1551.000000
# 25%    95660.000000    2.000000    1.000000   952.000000  145000.000000
# 50%    95762.000000    3.000000    2.000000  1304.000000  213750.000000
# 75%    95828.000000    4.000000    2.000000  1718.000000  300000.000000
# max    95864.000000    8.000000    5.000000  5822.000000  884790.000000
#
#          latitude   longitude
# count  985.000000  985.000000
# mean    38.607732 -121.355982
# std      0.145433    0.138278
# min     38.241514 -121.551704
# 25%     38.482717 -121.446127
# 50%     38.626582 -121.376220
# 75%     38.695589 -121.295778
# max     39.020808 -120.597599
